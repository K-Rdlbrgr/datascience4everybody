# %% [markdown]
# # Stock Market API
#
# In this exercise, we are going to play around with the stock market API [iexcloud.io](https://iexcloud.io).
#
# The API documentation page of iexcloud.io can be found [here](https://iexcloud.io/docs/api/).
#
# Before we can use the API, we need to register and get an API key.

# %%
# Let's start with some imports
# %matplotlib inline
import numpy as np
import pandas as pd
import matplotlib
import requests

# %%
import os

# We assign an environmental variable with the API key
# os.environ['IEXCLOUD_API_KEY'] = SECRET_KEY

# Or we can also just publish it here since it is a public key
PUBLIC_API_KEY = 'pk_ea47f959a3b4476cac4d30873370b5b0'

# Base URL
base_url = 'https://cloud.iexapis.com/'

# Get my personal API key from the environmental variable
PUBLIC_API_KEY = os.environ.get('IEXCLOUD_API_KEY')
print(PUBLIC_API_KEY)
# Out:
# pk_ea47f959a3b4476cac4d30873370b5b0

# %%
# Set ticker and time period
symbol = 'aapl'
time_range = '3m'

# Call the Apple stock for the last 3 months
aapl_url = f'{base_url}stable/stock/{symbol}/chart/{time_range}?token={PUBLIC_API_KEY}'

# Let's call the API wit our url to get the data for appl in a JSON format
api_data = requests.get(aapl_url).json()
api_data
# Out:
# 0,
#   'changePercent': 0,
#   'label': 'May 1, 20',
#   'changeOverTime': 0},
#  {'date': '2020-05-04',
#   'open': 289.17,
#   'close': 293.16,
#   'high': 293.69,
#   'low': 286.32,
#   'volume': 33391986,
#   'uOpen': 289.17,
#   'uClose': 293.16,
#   'uHigh': 293.69,
#   'uLow': 286.32,
#   'uVolume': 33391986,
#   'change': 4.09,
#   'changePercent': 1.4149,
#   'label': 'May 4, 20',
#   'changeOverTime': 0.014149},
#  {'date': '2020-05-05',
#   'open': 295.06,
#   'close': 297.56,
#   'high': 301,
#   'low': 294.46,
#   'volume': 36937795,
#   'uOpen': 295.06,
#   'uClose': 297.56,
#   'uHigh': 301,
#   'uLow': 294.46,
#   'uVolume': 36937795,
#   'change': 4.4,
#   'changePercent': 1.5009,
#   'label': 'May 5, 20',
#   'changeOverTime': 0.02937},
#  {'date': '2020-05-06',
#   'open': 300.46,
#   'close': 300.63,
#   'high': 303.24,
#   'low': 298.87,
#   'volume': 35583438,
#   'uOpen': 300.46,
#   'uClose': 300.63,
#   'uHigh': 303.24,
#   'uLow': 298.87,
#   'uVolume': 35583438,
#   'change': 3.07,
#   'changePercent': 1.0317,
#   'label': 'May 6, 20',
#   'changeOverTime': 0.03999},
#  {'date': '2020-05-07',
#   'open': 303.22,
#   'close': 303.74,
#   'high': 305.17,
#   'low': 301.97,
#   'volume': 28803764,
#   'uOpen': 303.22,
#   'uClose': 303.74,
#   'uHigh': 305.17,
#   'uLow': 301.97,
#   'uVolume': 28803764,
#   'change': 3.11,
#   'changePercent': 1.0345,
#   'label': 'May 7, 20',
#   'changeOverTime': 0.050749},
#  {'date': '2020-05-08',
#   'open': 305.64,
#   'close': 310.13,
#   'high': 310.35,
#   'low': 304.29,
#   'volume': 33511985,
#   'uOpen': 305.64,
#   'uClose': 310.13,
#   'uHigh': 310.35,
#   'uLow': 304.29,
#   'uVolume': 33511985,
#   'change': 6.39,
#   'changePercent': 2.1038,
#   'label': 'May 8, 20',
#   'changeOverTime': 0.072854},
#  {'date': '2020-05-11',
#   'open': 308.1,
#   'close': 315.01,
#   'high': 317.05,
#   'low': 307.24,
#   'volume': 36486561,
#   'uOpen': 308.1,
#   'uClose': 315.01,
#   'uHigh': 317.05,
#   'uLow': 307.24,
#   'uVolume': 36486561,
#   'change': 4.88,
#   'changePercent': 1.5735,
#   'label': 'May 11, 20',
#   'changeOverTime': 0.089736},
#  {'date': '2020-05-12',
#   'open': 317.83,
#   'close': 311.41,
#   'high': 319.69,
#   'low': 310.91,
#   'volume': 40575263,
#   'uOpen': 317.83,
#   'uClose': 311.41,
#   'uHigh': 319.69,
#   'uLow': 310.91,
#   'uVolume': 40575263,
#   'change': -3.6,
#   'changePercent': -1.1428,
#   'label': 'May 12, 20',
#   'changeOverTime': 0.077282},
#  {'date': '2020-05-13',
#   'open': 312.15,
#   'close': 307.65,
#   'high': 315.95,
#   'low': 303.21,
#   'volume': 50155639,
#   'uOpen': 312.15,
#   'uClose': 307.65,
#   'uHigh': 315.95,
#   'uLow': 303.21,
#   'uVolume': 50155639,
#   'change': -3.76,
#   'changePercent': -1.2074,
#   'label': 'May 13, 20',
#   'changeOverTime': 0.064275},
#  {'date': '2020-05-14',
#   'open': 304.51,
#   'close': 309.54,
#   'high': 309.79,
#   'low': 301.53,
#   'volume': 39732269,
#   'uOpen': 304.51,
#   'uClose': 309.54,
#   'uHigh': 309.79,
#   'uLow': 301.53,
#   'uVolume': 39732269,
#   'change': 1.89,
#   'changePercent': 0.6143,
#   'label': 'May 14, 20',
#   'changeOverTime': 0.070813},
#  {'date': '2020-05-15',
#   'open': 300.35,
#   'close': 307.71,
#   'high': 307.9,
#   'low': 300.21,
#   'volume': 41587094,
#   'uOpen': 300.35,
#   'uClose': 307.71,
#   'uHigh': 307.9,
#   'uLow': 300.21,
#   'uVolume': 41587094,
#   'change': -1.83,
#   'changePercent': -0.5912,
#   'label': 'May 15, 20',
#   'changeOverTime': 0.064483},
#  {'date': '2020-05-18',
#   'open': 313.17,
#   'close': 314.96,
#   'high': 316.5,
#   'low': 310.32,
#   'volume': 33843125,
#   'uOpen': 313.17,
#   'uClose': 314.96,
#   'uHigh': 316.5,
#   'uLow': 310.32,
#   'uVolume': 33843125,
#   'change': 7.25,
#   'changePercent': 2.3561,
#   'label': 'May 18, 20',
#   'changeOverTime': 0.089563},
#  {'date': '2020-05-19',
#   'open': 315.03,
#   'close': 313.14,
#   'high': 318.52,
#   'low': 313.01,
#   'volume': 25432385,
#   'uOpen': 315.03,
#   'uClose': 313.14,
#   'uHigh': 318.52,
#   'uLow': 313.01,
#   'uVolume': 25432385,
#   'change': -1.82,
#   'changePercent': -0.5779,
#   'label': 'May 19, 20',
#   'changeOverTime': 0.083267},
#  {'date': '2020-05-20',
#   'open': 316.68,
#   'close': 319.23,
#   'high': 319.52,
#   'low': 316.2,
#   'volume': 27876215,
#   'uOpen': 316.68,
#   'uClose': 319.23,
#   'uHigh': 319.52,
#   'uLow': 316.2,
#   'uVolume': 27876215,
#   'change': 6.09,
#   'changePercent': 1.9448,
#   'label': 'May 20, 20',
#   'changeOverTime': 0.104335},
#  {'date': '2020-05-21',
#   'open': 318.66,
#   'close': 316.85,
#   'high': 320.89,
#   'low': 315.87,
#   'volume': 25672211,
#   'uOpen': 318.66,
#   'uClose': 316.85,
#   'uHigh': 320.89,
#   'uLow': 315.87,
#   'uVolume': 25672211,
#   'change': -2.38,
#   'changePercent': -0.7455,
#   'label': 'May 21, 20',
#   'changeOverTime': 0.096101},
#  {'date': '2020-05-22',
#   'open': 315.77,
#   'close': 318.89,
#   'high': 319.23,
#   'low': 315.35,
#   'volume': 20450754,
#   'uOpen': 315.77,
#   'uClose': 318.89,
#   'uHigh': 319.23,
#   'uLow': 315.35,
#   'uVolume': 20450754,
#   'change': 2.04,
#   'changePercent': 0.6438,
#   'label': 'May 22, 20',
#   'changeOverTime': 0.103158},
#  {'date': '2020-05-26',
#   'open': 323.5,
#   'close': 316.73,
#   'high': 324.24,
#   'low': 316.5,
#   'volume': 31380454,
#   'uOpen': 323.5,
#   'uClose': 316.73,
#   'uHigh': 324.24,
#   'uLow': 316.5,
#   'uVolume': 31380454,
#   'change': -2.16,
#   'changePercent': -0.6773,
#   'label': 'May 26, 20',
#   'changeOverTime': 0.095686},
#  {'date': '2020-05-27',
#   'open': 316.14,
#   'close': 318.11,
#   'high': 318.71,
#   'low': 313.09,
#   'volume': 28236274,
#   'uOpen': 316.14,
#   'uClose': 318.11,
#   'uHigh': 318.71,
#   'uLow': 313.09,
#   'uVolume': 28236274,
#   'change': 1.38,
#   'changePercent': 0.4357,
#   'label': 'May 27, 20',
#   'changeOverTime': 0.10046},
#  {'date': '2020-05-28',
#   'open': 316.77,
#   'close': 318.25,
#   'high': 323.44,
#   'low': 315.63,
#   'volume': 33449103,
#   'uOpen': 316.77,
#   'uClose': 318.25,
#   'uHigh': 323.44,
#   'uLow': 315.63,
#   'uVolume': 33449103,
#   'change': 0.14,
#   'changePercent': 0.044,
#   'label': 'May 28, 20',
#   'changeOverTime': 0.100944},
#  {'date': '2020-05-29',
#   'open': 319.25,
#   'close': 317.94,
#   'high': 321.15,
#   'low': 316.47,
#   'volume': 38399532,
#   'uOpen': 319.25,
#   'uClose': 317.94,
#   'uHigh': 321.15,
#   'uLow': 316.47,
#   'uVolume': 38399532,
#   'change': -0.31,
#   'changePercent': -0.0974,
#   'label': 'May 29, 20',
#   'changeOverTime': 0.099872},
#  {'date': '2020-06-01',
#   'open': 317.75,
#   'close': 321.85,
#   'high': 322.35,
#   'low': 317.21,
#   'volume': 20254653,
#   'uOpen': 317.75,
#   'uClose': 321.85,
#   'uHigh': 322.35,
#   'uLow': 317.21,
#   'uVolume': 20254653,
#   'change': 3.91,
#   'changePercent': 1.2298,
#   'label': 'Jun 1, 20',
#   'changeOverTime': 0.113398},
#  {'date': '2020-06-02',
#   'open': 320.75,
#   'close': 323.34,
#   'high': 323.44,
#   'low': 318.93,
#   'volume': 21910704,
#   'uOpen': 320.75,
#   'uClose': 323.34,
#   'uHigh': 323.44,
#   'uLow': 318.93,
#   'uVolume': 21910704,
#   'change': 1.49,
#   'changePercent': 0.4629,
#   'label': 'Jun 2, 20',
#   'changeOverTime': 0.118553},
#  {'date': '2020-06-03',
#   'open': 324.66,
#   'close': 325.12,
#   'high': 326.2,
#   'low': 322.3,
#   'volume': 26122804,
#   'uOpen': 324.66,
#   'uClose': 325.12,
#   'uHigh': 326.2,
#   'uLow': 322.3,
#   'uVolume': 26122804,
#   'change': 1.78,
#   'changePercent': 0.5505,
#   'label': 'Jun 3, 20',
#   'changeOverTime': 0.12471},
#  {'date': '2020-06-04',
#   'open': 324.39,
#   'close': 322.32,
#   'high': 325.62,
#   'low': 320.78,
#   'volume': 21890091,
#   'uOpen': 324.39,
#   'uClose': 322.32,
#   'uHigh': 325.62,
#   'uLow': 320.78,
#   'uVolume': 21890091,
#   'change': -2.8,
#   'changePercent': -0.8612,
#   'label': 'Jun 4, 20',
#   'changeOverTime': 0.115024},
#  {'date': '2020-06-05',
#   'open': 323.35,
#   'close': 331.5,
#   'high': 331.75,
#   'low': 323.23,
#   'volume': 34312550,
#   'uOpen': 323.35,
#   'uClose': 331.5,
#   'uHigh': 331.75,
#   'uLow': 323.23,
#   'uVolume': 34312550,
#   'change': 9.18,
#   'changePercent': 2.8481,
#   'label': 'Jun 5, 20',
#   'changeOverTime': 0.146781},
#  {'date': '2020-06-08',
#   'open': 330.25,
#   'close': 333.46,
#   'high': 333.6,
#   'low': 327.32,
#   'volume': 23913634,
#   'uOpen': 330.25,
#   'uClose': 333.46,
#   'uHigh': 333.6,
#   'uLow': 327.32,
#   'uVolume': 23913634,
#   'change': 1.96,
#   'changePercent': 0.5913,
#   'label': 'Jun 8, 20',
#   'changeOverTime': 0.153561},
#  {'date': '2020-06-09',
#   'open': 332.14,
#   'close': 343.99,
#   'high': 345.61,
#   'low': 332.01,
#   'volume': 36928091,
#   'uOpen': 332.14,
#   'uClose': 343.99,
#   'uHigh': 345.61,
#   'uLow': 332.01,
#   'uVolume': 36928091,
#   'change': 10.53,
#   'changePercent': 3.1578,
#   'label': 'Jun 9, 20',
#   'changeOverTime': 0.189989},
#  {'date': '2020-06-10',
#   'open': 347.9,
#   'close': 352.84,
#   'high': 354.77,
#   'low': 346.09,
#   'volume': 41662938,
#   'uOpen': 347.9,
#   'uClose': 352.84,
#   'uHigh': 354.77,
#   'uLow': 346.09,
#   'uVolume': 41662938,
#   'change': 8.85,
#   'changePercent': 2.5727,
#   'label': 'Jun 10, 20',
#   'changeOverTime': 0.220604},
#  {'date': '2020-06-11',
#   'open': 349.31,
#   'close': 335.9,
#   'high': 351.06,
#   'low': 335.48,
#   'volume': 50415613,
#   'uOpen': 349.31,
#   'uClose': 335.9,
#   'uHigh': 351.06,
#   'uLow': 335.48,
#   'uVolume': 50415613,
#   'change': -16.94,
#   'changePercent': -4.801,
#   'label': 'Jun 11, 20',
#   'changeOverTime': 0.162002},
#  {'date': '2020-06-12',
#   'open': 344.72,
#   'close': 338.8,
#   'high': 347.8,
#   'low': 334.22,
#   'volume': 50036513,
#   'uOpen': 344.72,
#   'uClose': 338.8,
#   'uHigh': 347.8,
#   'uLow': 334.22,
#   'uVolume': 50036513,
#   'change': 2.9,
#   'changePercent': 0.8634,
#   'label': 'Jun 12, 20',
#   'changeOverTime': 0.172034},
#  {'date': '2020-06-15',
#   'open': 333.25,
#   'close': 342.99,
#   'high': 345.68,
#   'low': 332.58,
#   'volume': 34702230,
#   'uOpen': 333.25,
#   'uClose': 342.99,
#   'uHigh': 345.68,
#   'uLow': 332.58,
#   'uVolume': 34702230,
#   'change': 4.19,
#   'changePercent': 1.2367,
#   'label': 'Jun 15, 20',
#   'changeOverTime': 0.186529},
#  {'date': '2020-06-16',
#   'open': 351.46,
#   'close': 352.08,
#   'high': 353.2,
#   'low': 344.72,
#   'volume': 41357182,
#   'uOpen': 351.46,
#   'uClose': 352.08,
#   'uHigh': 353.2,
#   'uLow': 344.72,
#   'uVolume': 41357182,
#   'change': 9.09,
#   'changePercent': 2.6502,
#   'label': 'Jun 16, 20',
#   'changeOverTime': 0.217975},
#  {'date': '2020-06-17',
#   'open': 355.15,
#   'close': 351.59,
#   'high': 355.4,
#   'low': 351.09,
#   'volume': 28601626,
#   'uOpen': 355.15,
#   'uClose': 351.59,
#   'uHigh': 355.4,
#   'uLow': 351.09,
#   'uVolume': 28601626,
#   'change': -0.49,
#   'changePercent': -0.1392,
#   'label': 'Jun 17, 20',
#   'changeOverTime': 0.21628},
#  {'date': '2020-06-18',
#   'open': 351.41,
#   'close': 351.73,
#   'high': 353.45,
#   'low': 349.22,
#   'volume': 24205096,
#   'uOpen': 351.41,
#   'uClose': 351.73,
#   'uHigh': 353.45,
#   'uLow': 349.22,
#   'uVolume': 24205096,
#   'change': 0.14,
#   'changePercent': 0.0398,
#   'label': 'Jun 18, 20',
#   'changeOverTime': 0.216764},
#  {'date': '2020-06-19',
#   'open': 354.64,
#   'close': 349.72,
#   'high': 356.56,
#   'low': 345.15,
#   'volume': 66118952,
#   'uOpen': 354.64,
#   'uClose': 349.72,
#   'uHigh': 356.56,
#   'uLow': 345.15,
#   'uVolume': 66118952,
#   'change': -2.01,
#   'changePercent': -0.5715,
#   'label': 'Jun 19, 20',
#   'changeOverTime': 0.209811},
#  {'date': '2020-06-22',
#   'open': 351.34,
#   'close': 358.87,
#   'high': 359.46,
#   'low': 351.15,
#   'volume': 33861316,
#   'uOpen': 351.34,
#   'uClose': 358.87,
#   'uHigh': 359.46,
#   'uLow': 351.15,
#   'uVolume': 33861316,
#   'change': 9.15,
#   'changePercent': 2.6164,
#   'label': 'Jun 22, 20',
#   'changeOverTime': 0.241464},
#  {'date': '2020-06-23',
#   'open': 364,
#   'close': 366.53,
#   'high': 372.38,
#   'low': 362.27,
#   'volume': 53038869,
#   'uOpen': 364,
#   'uClose': 366.53,
#   'uHigh': 372.38,
#   'uLow': 362.27,
#   'uVolume': 53038869,
#   'change': 7.66,
#   'changePercent': 2.1345,
#   'label': 'Jun 23, 20',
#   'changeOverTime': 0.267963},
#  {'date': '2020-06-24',
#   'open': 365,
#   'close': 360.06,
#   'high': 368.79,
#   'low': 358.52,
#   'volume': 48155849,
#   'uOpen': 365,
#   'uClose': 360.06,
#   'uHigh': 368.79,
#   'uLow': 358.52,
#   'uVolume': 48155849,
#   'change': -6.47,
#   'changePercent': -1.7652,
#   'label': 'Jun 24, 20',
#   'changeOverTime': 0.245581},
#  {'date': '2020-06-25',
#   'open': 360.7,
#   'close': 364.84,
#   'high': 365,
#   'low': 357.57,
#   'volume': 34380628,
#   'uOpen': 360.7,
#   'uClose': 364.84,
#   'uHigh': 365,
#   'uLow': 357.57,
#   'uVolume': 34380628,
#   'change': 4.78,
#   'changePercent': 1.3276,
#   'label': 'Jun 25, 20',
#   'changeOverTime': 0.262116},
#  {'date': '2020-06-26',
#   'open': 364.41,
#   'close': 353.63,
#   'high': 365.32,
#   'low': 353.02,
#   'volume': 51314211,
#   'uOpen': 364.41,
#   'uClose': 353.63,
#   'uHigh': 365.32,
#   'uLow': 353.02,
#   'uVolume': 51314211,
#   'change': -11.21,
#   'changePercent': -3.0726,
#   'label': 'Jun 26, 20',
#   'changeOverTime': 0.223337},
#  {'date': '2020-06-29',
#   'open': 353.25,
#   'close': 361.78,
#   'high': 362.17,
#   'low': 351.28,
#   'volume': 32661519,
#   'uOpen': 353.25,
#   'uClose': 361.78,
#   'uHigh': 362.17,
#   'uLow': 351.28,
#   'uVolume': 32661519,
#   'change': 8.15,
#   'changePercent': 2.3047,
#   'label': 'Jun 29, 20',
#   'changeOverTime': 0.251531},
#  {'date': '2020-06-30',
#   'open': 360.08,
#   'close': 364.8,
#   'high': 365.98,
#   'low': 360,
#   'volume': 35055821,
#   'uOpen': 360.08,
#   'uClose': 364.8,
#   'uHigh': 365.98,
#   'uLow': 360,
#   'uVolume': 35055821,
#   'change': 3.02,
#   'changePercent': 0.8348,
#   'label': 'Jun 30, 20',
#   'changeOverTime': 0.261978},
#  {'date': '2020-07-01',
#   'open': 365.12,
#   'close': 364.11,
#   'high': 367.36,
#   'low': 363.91,
#   'volume': 27684309,
#   'uOpen': 365.12,
#   'uClose': 364.11,
#   'uHigh': 367.36,
#   'uLow': 363.91,
#   'uVolume': 27684309,
#   'change': -0.69,
#   'changePercent': -0.1891,
#   'label': 'Jul 1, 20',
#   'changeOverTime': 0.259591},
#  {'date': '2020-07-02',
#   'open': 367.85,
#   'close': 364.11,
#   'high': 370.47,
#   'low': 363.64,
#   'volume': 28510367,
#   'uOpen': 367.85,
#   'uClose': 364.11,
#   'uHigh': 370.47,
#   'uLow': 363.64,
#   'uVolume': 28510367,
#   'change': 0,
#   'changePercent': 0,
#   'label': 'Jul 2, 20',
#   'changeOverTime': 0.259591},
#  {'date': '2020-07-06',
#   'open': 370,
#   'close': 373.85,
#   'high': 375.78,
#   'low': 369.87,
#   'volume': 29663913,
#   'uOpen': 370,
#   'uClose': 373.85,
#   'uHigh': 375.78,
#   'uLow': 369.87,
#   'uVolume': 29663913,
#   'change': 9.74,
#   'changePercent': 2.675,
#   'label': 'Jul 6, 20',
#   'changeOverTime': 0.293285},
#  {'date': '2020-07-07',
#   'open': 375.41,
#   'close': 372.69,
#   'high': 378.62,
#   'low': 372.23,
#   'volume': 28106114,
#   'uOpen': 375.41,
#   'uClose': 372.69,
#   'uHigh': 378.62,
#   'uLow': 372.23,
#   'uVolume': 28106114,
#   'change': -1.16,
#   'changePercent': -0.3103,
#   'label': 'Jul 7, 20',
#   'changeOverTime': 0.289272},
#  {'date': '2020-07-08',
#   'open': 376.72,
#   'close': 381.37,
#   'high': 381.5,
#   'low': 376.36,
#   'volume': 29272970,
#   'uOpen': 376.72,
#   'uClose': 381.37,
#   'uHigh': 381.5,
#   'uLow': 376.36,
#   'uVolume': 29272970,
#   'change': 8.68,
#   'changePercent': 2.329,
#   'label': 'Jul 8, 20',
#   'changeOverTime': 0.3193},
#  {'date': '2020-07-09',
#   'open': 385.05,
#   'close': 382.73,
#   'high': 385.27,
#   'low': 378.69,
#   'volume': 31410652,
#   'uOpen': 385.05,
#   'uClose': 382.73,
#   'uHigh': 385.27,
#   'uLow': 378.69,
#   'uVolume': 31410652,
#   'change': 1.36,
#   'changePercent': 0.3566,
#   'label': 'Jul 9, 20',
#   'changeOverTime': 0.324005},
#  {'date': '2020-07-10',
#   'open': 381.34,
#   'close': 383.68,
#   'high': 383.92,
#   'low': 378.82,
#   'volume': 22564330,
#   'uOpen': 381.34,
#   'uClose': 383.68,
#   'uHigh': 383.92,
#   'uLow': 378.82,
#   'uVolume': 22564330,
#   'change': 0.95,
#   'changePercent': 0.2482,
#   'label': 'Jul 10, 20',
#   'changeOverTime': 0.327291},
#  {'date': '2020-07-13',
#   'open': 389.06,
#   'close': 381.91,
#   'high': 399.82,
#   'low': 381.03,
#   'volume': 47912285,
#   'uOpen': 389.06,
#   'uClose': 381.91,
#   'uHigh': 399.82,
#   'uLow': 381.03,
#   'uVolume': 47912285,
#   'change': -1.77,
#   'changePercent': -0.4613,
#   'label': 'Jul 13, 20',
#   'changeOverTime': 0.321168},
#  {'date': '2020-07-14',
#   'open': 379.36,
#   'close': 388.23,
#   'high': 389.02,
#   'low': 375.51,
#   'volume': 42747341,
#   'uOpen': 379.36,
#   'uClose': 388.23,
#   'uHigh': 389.02,
#   'uLow': 375.51,
#   'uVolume': 42747341,
#   'change': 6.32,
#   'changePercent': 1.6548,
#   'label': 'Jul 14, 20',
#   'changeOverTime': 0.343031},
#  {'date': '2020-07-15',
#   'open': 395.96,
#   'close': 390.9,
#   'high': 396.99,
#   'low': 385.96,
#   'volume': 38299483,
#   'uOpen': 395.96,
#   'uClose': 390.9,
#   'uHigh': 396.99,
#   'uLow': 385.96,
#   'uVolume': 38299483,
#   'change': 2.67,
#   'changePercent': 0.6877,
#   'label': 'Jul 15, 20',
#   'changeOverTime': 0.352268},
#  {'date': '2020-07-16',
#   'open': 386.25,
#   'close': 386.09,
#   'high': 389.62,
#   'low': 383.62,
#   'volume': 27644418,
#   'uOpen': 386.25,
#   'uClose': 386.09,
#   'uHigh': 389.62,
#   'uLow': 383.62,
#   'uVolume': 27644418,
#   'change': -4.81,
#   'changePercent': -1.2305,
#   'label': 'Jul 16, 20',
#   'changeOverTime': 0.335628},
#  {'date': '2020-07-17',
#   'open': 387.95,
#   'close': 385.31,
#   'high': 388.59,
#   'low': 383.36,
#   'volume': 23046725,
#   'uOpen': 387.95,
#   'uClose': 385.31,
#   'uHigh': 388.59,
#   'uLow': 383.36,
#   'uVolume': 23046725,
#   'change': -0.78,
#   'changePercent': -0.202,
#   'label': 'Jul 17, 20',
#   'changeOverTime': 0.33293},
#  {'date': '2020-07-20',
#   'open': 385.67,
#   'close': 393.43,
#   'high': 394,
#   'low': 384.25,
#   'volume': 22579477,
#   'uOpen': 385.67,
#   'uClose': 393.43,
#   'uHigh': 394,
#   'uLow': 384.25,
#   'uVolume': 22579477,
#   'change': 8.12,
#   'changePercent': 2.1074,
#   'label': 'Jul 20, 20',
#   'changeOverTime': 0.36102},
#  {'date': '2020-07-21',
#   'open': 396.69,
#   'close': 388,
#   'high': 397,
#   'low': 386.97,
#   'volume': 25911459,
#   'uOpen': 396.69,
#   'uClose': 388,
#   'uHigh': 397,
#   'uLow': 386.97,
#   'uVolume': 25911459,
#   'change': -5.43,
#   'changePercent': -1.3802,
#   'label': 'Jul 21, 20',
#   'changeOverTime': 0.342235},
#  {'date': '2020-07-22',
#   'open': 386.77,
#   'close': 389.09,
#   'high': 391.9,
#   'low': 386.41,
#   'volume': 22250413,
#   'uOpen': 386.77,
#   'uClose': 389.09,
#   'uHigh': 391.9,
#   'uLow': 386.41,
#   'uVolume': 22250413,
#   'change': 1.09,
#   'changePercent': 0.2809,
#   'label': 'Jul 22, 20',
#   'changeOverTime': 0.346006},
#  {'date': '2020-07-23',
#   'open': 387.99,
#   'close': 371.38,
#   'high': 388.31,
#   'low': 368.04,
#   'volume': 49251108,
#   'uOpen': 387.99,
#   'uClose': 371.38,
#   'uHigh': 388.31,
#   'uLow': 368.04,
#   'uVolume': 49251108,
#   'change': -17.71,
#   'changePercent': -4.5516,
#   'label': 'Jul 23, 20',
#   'changeOverTime': 0.284741},
#  {'date': '2020-07-24',
#   'open': 363.95,
#   'close': 370.46,
#   'high': 371.88,
#   'low': 356.58,
#   'volume': 46359716,
#   'uOpen': 363.95,
#   'uClose': 370.46,
#   'uHigh': 371.88,
#   'uLow': 356.58,
#   'uVolume': 46359716,
#   'change': -0.92,
#   'changePercent': -0.2477,
#   'label': 'Jul 24, 20',
#   'changeOverTime': 0.281558},
#  {'date': '2020-07-27',
#   'open': 374.84,
#   'close': 379.24,
#   'high': 379.62,
#   'low': 373.92,
#   'volume': 30303548,
#   'uOpen': 374.84,
#   'uClose': 379.24,
#   'uHigh': 379.62,
#   'uLow': 373.92,
#   'uVolume': 30303548,
#   'change': 8.78,
#   'changePercent': 2.37,
#   'label': 'Jul 27, 20',
#   'changeOverTime': 0.311931},
#  {'date': '2020-07-28',
#   'open': 377.47,
#   'close': 373.01,
#   'high': 378.2,
#   'low': 372.99,
#   'volume': 25906375,
#   'uOpen': 377.47,
#   'uClose': 373.01,
#   'uHigh': 378.2,
#   'uLow': 372.99,
#   'uVolume': 25906375,
#   'change': -6.23,
#   'changePercent': -1.6428,
#   'label': 'Jul 28, 20',
#   'changeOverTime': 0.290379},
#  {'date': '2020-07-29',
#   'open': 375,
#   'close': 380.16,
#   'high': 380.92,
#   'low': 374.85,
#   'volume': 22582314,
#   'uOpen': 375,
#   'uClose': 380.16,
#   'uHigh': 380.92,
#   'uLow': 374.85,
#   'uVolume': 22582314,
#   'change': 7.15,
#   'changePercent': 1.9168,
#   'label': 'Jul 29, 20',
#   'changeOverTime': 0.315114},
#  {'date': '2020-07-30',
#   'open': 376.75,
#   'close': 384.76,
#   'high': 385.19,
#   'low': 375.07,
#   'volume': 39532505,
#   'uOpen': 376.75,
#   'uClose': 384.76,
#   'uHigh': 385.19,
#   'uLow': 375.07,
#   'uVolume': 39532505,
#   'change': 4.6,
#   'changePercent': 1.21,
#   'label': 'Jul 30, 20',
#   'changeOverTime': 0.331027},
#  {'date': '2020-07-31',
#   'open': 411.54,
#   'close': 425.04,
#   'high': 425.66,
#   'low': 403.3,
#   'volume': 93573867,
#   'uOpen': 411.54,
#   'uClose': 425.04,
#   'uHigh': 425.66,
#   'uLow': 403.3,
#   'uVolume': 93573867,
#   'change': 40.28,
#   'changePercent': 10.4689,
#   'label': 'Jul 31, 20',
#   'changeOverTime': 0.47037}]

# %%
# Now we create a dataframe based on the JSON file
aapl_df = pd.DataFrame.from_dict(api_data)
aapl_df
# Out:
#           date    open   close    high     low    volume   uOpen  uClose  \
# 0   2020-05-01  286.25  289.07  299.00  285.85  60154175  286.25  289.07
# 1   2020-05-04  289.17  293.16  293.69  286.32  33391986  289.17  293.16
# 2   2020-05-05  295.06  297.56  301.00  294.46  36937795  295.06  297.56
# 3   2020-05-06  300.46  300.63  303.24  298.87  35583438  300.46  300.63
# 4   2020-05-07  303.22  303.74  305.17  301.97  28803764  303.22  303.74
# ..         ...     ...     ...     ...     ...       ...     ...     ...
# 59  2020-07-27  374.84  379.24  379.62  373.92  30303548  374.84  379.24
# 60  2020-07-28  377.47  373.01  378.20  372.99  25906375  377.47  373.01
# 61  2020-07-29  375.00  380.16  380.92  374.85  22582314  375.00  380.16
# 62  2020-07-30  376.75  384.76  385.19  375.07  39532505  376.75  384.76
# 63  2020-07-31  411.54  425.04  425.66  403.30  93573867  411.54  425.04
#
#      uHigh    uLow   uVolume  change  changePercent       label  \
# 0   299.00  285.85  60154175    0.00         0.0000   May 1, 20
# 1   293.69  286.32  33391986    4.09         1.4149   May 4, 20
# 2   301.00  294.46  36937795    4.40         1.5009   May 5, 20
# 3   303.24  298.87  35583438    3.07         1.0317   May 6, 20
# 4   305.17  301.97  28803764    3.11         1.0345   May 7, 20
# ..     ...     ...       ...     ...            ...         ...
# 59  379.62  373.92  30303548    8.78         2.3700  Jul 27, 20
# 60  378.20  372.99  25906375   -6.23        -1.6428  Jul 28, 20
# 61  380.92  374.85  22582314    7.15         1.9168  Jul 29, 20
# 62  385.19  375.07  39532505    4.60         1.2100  Jul 30, 20
# 63  425.66  403.30  93573867   40.28        10.4689  Jul 31, 20
#
#     changeOverTime
# 0         0.000000
# 1         0.014149
# 2         0.029370
# 3         0.039990
# 4         0.050749
# ..             ...
# 59        0.311931
# 60        0.290379
# 61        0.315114
# 62        0.331027
# 63        0.470370
#
# [64 rows x 15 columns]

# %%
# First things first, we will have a look at the columns
appl_df.dtypes
# Out:
# date              datetime64[ns]
# open                     float64
# close                    float64
# high                     float64
# low                      float64
# volume                     int64
# uOpen                    float64
# uClose                   float64
# uHigh                    float64
# uLow                     float64
# uVolume                    int64
# change                   float64
# changePercent            float64
# label                     object
# changeOverTime           float64
# dtype: object

# %%
# We would like to convert the date column to a datetime object
appl_df['date'] = pd.to_datetime(aapl_df['date'])
aapl_df.dtypes
# Out:
# date               object
# open              float64
# close             float64
# high              float64
# low               float64
# volume              int64
# uOpen             float64
# uClose            float64
# uHigh             float64
# uLow              float64
# uVolume             int64
# change            float64
# changePercent     float64
# label              object
# changeOverTime    float64
# dtype: object

# %%
# Noe we set the date as the index
aapl_df.set_index('date')
# Out:
#               open   close    high     low    volume   uOpen  uClose   uHigh  \
# date
# 2020-05-01  286.25  289.07  299.00  285.85  60154175  286.25  289.07  299.00
# 2020-05-04  289.17  293.16  293.69  286.32  33391986  289.17  293.16  293.69
# 2020-05-05  295.06  297.56  301.00  294.46  36937795  295.06  297.56  301.00
# 2020-05-06  300.46  300.63  303.24  298.87  35583438  300.46  300.63  303.24
# 2020-05-07  303.22  303.74  305.17  301.97  28803764  303.22  303.74  305.17
# ...            ...     ...     ...     ...       ...     ...     ...     ...
# 2020-07-27  374.84  379.24  379.62  373.92  30303548  374.84  379.24  379.62
# 2020-07-28  377.47  373.01  378.20  372.99  25906375  377.47  373.01  378.20
# 2020-07-29  375.00  380.16  380.92  374.85  22582314  375.00  380.16  380.92
# 2020-07-30  376.75  384.76  385.19  375.07  39532505  376.75  384.76  385.19
# 2020-07-31  411.54  425.04  425.66  403.30  93573867  411.54  425.04  425.66
#
#               uLow   uVolume  change  changePercent       label  \
# date
# 2020-05-01  285.85  60154175    0.00         0.0000   May 1, 20
# 2020-05-04  286.32  33391986    4.09         1.4149   May 4, 20
# 2020-05-05  294.46  36937795    4.40         1.5009   May 5, 20
# 2020-05-06  298.87  35583438    3.07         1.0317   May 6, 20
# 2020-05-07  301.97  28803764    3.11         1.0345   May 7, 20
# ...            ...       ...     ...            ...         ...
# 2020-07-27  373.92  30303548    8.78         2.3700  Jul 27, 20
# 2020-07-28  372.99  25906375   -6.23        -1.6428  Jul 28, 20
# 2020-07-29  374.85  22582314    7.15         1.9168  Jul 29, 20
# 2020-07-30  375.07  39532505    4.60         1.2100  Jul 30, 20
# 2020-07-31  403.30  93573867   40.28        10.4689  Jul 31, 20
#
#             changeOverTime
# date
# 2020-05-01        0.000000
# 2020-05-04        0.014149
# 2020-05-05        0.029370
# 2020-05-06        0.039990
# 2020-05-07        0.050749
# ...                    ...
# 2020-07-27        0.311931
# 2020-07-28        0.290379
# 2020-07-29        0.315114
# 2020-07-30        0.331027
# 2020-07-31        0.470370
#
# [64 rows x 14 columns]

# %%
# Now let/s plot the closing prices
aapl_df['close'].plot()
# Out:
# <AxesSubplot:>

# %%
# To make the different values more readable, we use the figsize attribute to adjust the width and height
aapl_df[['open', 'close', 'high', 'low']].plot(figsize=(20,8))
# Out:
# <AxesSubplot:>

# %%
# Let's get Amazon stock prices since last year
symbol = 'amzn'
time_range = '1y'

# Call the Amazon stock for the last year
amzn_url = f'{base_url}stable/stock/{symbol}/chart/{time_range}?token={PUBLIC_API_KEY}'

# Let's call the API wit our url to get the data for appl in a JSON format
api_data = requests.get(amzn_url).json()

# Now we create a dataframe based on the JSON file
amzn_df = pd.DataFrame.from_dict(api_data)

# We would like to convert the date column to a datetime object
amzn_df['date'] = pd.to_datetime(amzn_df['date'])

# Noe we set the date as the index
amzn_df.set_index('date')
# Out:
#                open    close     high      low   volume    uOpen   uClose  \
# date
# 2019-08-01  1871.72  1855.32  1897.92  1844.01  4713311  1871.72  1855.32
# 2019-08-02  1845.07  1823.24  1846.36  1808.02  4956225  1845.07  1823.24
# 2019-08-05  1770.22  1765.13  1788.67  1748.78  6058212  1770.22  1765.13
# 2019-08-06  1792.23  1787.83  1793.77  1753.40  5070258  1792.23  1787.83
# 2019-08-07  1773.99  1793.40  1798.93  1757.00  4526884  1773.99  1793.40
# ...             ...      ...      ...      ...      ...      ...      ...
# 2020-07-27  3062.00  3055.21  3098.00  3015.77  4170492  3062.00  3055.21
# 2020-07-28  3054.27  3000.33  3077.09  2995.76  3126651  3054.27  3000.33
# 2020-07-29  3030.99  3033.53  3039.16  2996.77  2974060  3030.99  3033.53
# 2020-07-30  3014.00  3051.88  3092.00  3005.00  6128265  3014.00  3051.88
# 2020-07-31  3244.00  3164.68  3246.82  3151.00  8083369  3244.00  3164.68
#
#               uHigh     uLow  uVolume  change  changePercent       label  \
# date
# 2019-08-01  1897.92  1844.01  4713311    0.00         0.0000   Aug 1, 19
# 2019-08-02  1846.36  1808.02  4956225  -32.08        -1.7291   Aug 2, 19
# 2019-08-05  1788.67  1748.78  6058212  -58.11        -3.1872   Aug 5, 19
# 2019-08-06  1793.77  1753.40  5070258   22.70         1.2860   Aug 6, 19
# 2019-08-07  1798.93  1757.00  4526884    5.57         0.3116   Aug 7, 19
# ...             ...      ...      ...     ...            ...         ...
# 2020-07-27  3098.00  3015.77  4170492   46.30         1.5388  Jul 27, 20
# 2020-07-28  3077.09  2995.76  3126651  -54.88        -1.7963  Jul 28, 20
# 2020-07-29  3039.16  2996.77  2974060   33.20         1.1065  Jul 29, 20
# 2020-07-30  3092.00  3005.00  6128265   18.35         0.6049  Jul 30, 20
# 2020-07-31  3246.82  3151.00  8083369  112.80         3.6961  Jul 31, 20
#
#             changeOverTime
# date
# 2019-08-01        0.000000
# 2019-08-02       -0.017291
# 2019-08-05       -0.048612
# 2019-08-06       -0.036376
# 2019-08-07       -0.033374
# ...                    ...
# 2020-07-27        0.646729
# 2020-07-28        0.617150
# 2020-07-29        0.635044
# 2020-07-30        0.644935
# 2020-07-31        0.705733
#
# [253 rows x 14 columns]

# %%
# Let's get Facebook statistics
symbol = 'fb'

# Call the Facebook stats
fb_url = f'{base_url}/stable/stock/{symbol}/stats/?token={PUBLIC_API_KEY}'

# Let's call the API with our url to get the data for appl in a JSON format
fb_marketcap = requests.get(fb_url).json()['marketcap']

fb_marketcap
# Out:
# 723302319785

# %%
# Let's get Facebook statistics
symbol = 'aapl'
time = 'quarter'

# Call the Facebook stats
aapl_url = f'{base_url}stable/stock/{symbol}/financials?token={PUBLIC_API_KEY}'

# Let's call the API with our url to get the data for appl in a JSON format
aapl_research = requests.get(aapl_url)

# %%
# Let's get the latest news of Tesla
symbol = 'tsla'

# Call the Facebook stats
tsla_url = f'{base_url}stable/stock/{symbol}/news/last/1?token={PUBLIC_API_KEY}'

# Let's call the API with our url to get the data for appl in a JSON format
tsla_news = requests.get(tsla_url).json()
tsla_news
# Out:
# [{'datetime': 1596352533000,
#   'headline': 'Tesla könnte mit neuer Fabrik schneller als in China sein',
#   'source': 'T-Online',
#   'url': 'https://cloud.iexapis.com/v1/news/article/60617163-72e0-4b30-8900-47287eccee43',
#   'summary': 'Die Fabrik von US-Elektroautobauer Tesla in Grünheide bei Berlin könnte nach Ansicht von Brandenburgs Wirtschaftsminister Jörg Steinbach (SPD) schneller gebaut werden als ein schon bestehendes Werk in China. "Das Ziel bei Tesla scheint es zu sein, die Bauzeit der "Gigafactory 3" in Shanghai noch ein',
#   'related': 'TSLA',
#   'image': 'https://cloud.iexapis.com/v1/news/image/60617163-72e0-4b30-8900-47287eccee43',
#   'lang': 'de',
#   'hasPaywall': False}]

# %%
# Let's get the latest news of Tesla
sector = 'energy'

# Call the Facebook stats
energy_url = f'{base_url}stable/stock/market/sector-performance?token={PUBLIC_API_KEY}'

# Let's call the API with our url to get the data for appl in a JSON format
energy_performance = requests.get(energy_url)

# %%
amzn_df
# Out:
#           date     open    close     high      low   volume    uOpen   uClose  \
# 0   2019-08-01  1871.72  1855.32  1897.92  1844.01  4713311  1871.72  1855.32
# 1   2019-08-02  1845.07  1823.24  1846.36  1808.02  4956225  1845.07  1823.24
# 2   2019-08-05  1770.22  1765.13  1788.67  1748.78  6058212  1770.22  1765.13
# 3   2019-08-06  1792.23  1787.83  1793.77  1753.40  5070258  1792.23  1787.83
# 4   2019-08-07  1773.99  1793.40  1798.93  1757.00  4526884  1773.99  1793.40
# ..         ...      ...      ...      ...      ...      ...      ...      ...
# 248 2020-07-27  3062.00  3055.21  3098.00  3015.77  4170492  3062.00  3055.21
# 249 2020-07-28  3054.27  3000.33  3077.09  2995.76  3126651  3054.27  3000.33
# 250 2020-07-29  3030.99  3033.53  3039.16  2996.77  2974060  3030.99  3033.53
# 251 2020-07-30  3014.00  3051.88  3092.00  3005.00  6128265  3014.00  3051.88
# 252 2020-07-31  3244.00  3164.68  3246.82  3151.00  8083369  3244.00  3164.68
#
#        uHigh     uLow  uVolume  change  changePercent       label  \
# 0    1897.92  1844.01  4713311    0.00         0.0000   Aug 1, 19
# 1    1846.36  1808.02  4956225  -32.08        -1.7291   Aug 2, 19
# 2    1788.67  1748.78  6058212  -58.11        -3.1872   Aug 5, 19
# 3    1793.77  1753.40  5070258   22.70         1.2860   Aug 6, 19
# 4    1798.93  1757.00  4526884    5.57         0.3116   Aug 7, 19
# ..       ...      ...      ...     ...            ...         ...
# 248  3098.00  3015.77  4170492   46.30         1.5388  Jul 27, 20
# 249  3077.09  2995.76  3126651  -54.88        -1.7963  Jul 28, 20
# 250  3039.16  2996.77  2974060   33.20         1.1065  Jul 29, 20
# 251  3092.00  3005.00  6128265   18.35         0.6049  Jul 30, 20
# 252  3246.82  3151.00  8083369  112.80         3.6961  Jul 31, 20
#
#      changeOverTime
# 0          0.000000
# 1         -0.017291
# 2         -0.048612
# 3         -0.036376
# 4         -0.033374
# ..              ...
# 248        0.646729
# 249        0.617150
# 250        0.635044
# 251        0.644935
# 252        0.705733
#
# [253 rows x 15 columns]
